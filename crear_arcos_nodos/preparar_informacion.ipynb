# %%
import pandas as pd

# %%
bd_inversionistas = pd.read_excel('Base-inicial.xlsx')
bd_inversionistas.head(5)
# Out:
#   Organization Name                       Headquarters Location  \
# 0           Tencent                  Shenzhen, Guangdong, China
# 1    Warburg Pincus           New York, New York, United States
# 2           Twitter    San Francisco, California, United States
# 3           Ubisoft  Montreuil-sous-bois, Ile-de-France, France
# 4            WeWork           New York, New York, United States
#
#   Operating Status Company Type  Number of Investments  \
# 0           Active   For Profit                  693.0
# 1           Active          NaN                  433.0
# 2           Active   For Profit                   10.0
# 3           Active   For Profit                    9.0
# 4           Active   For Profit                    9.0
#
#    Number of Lead Investments  Number of Diversity Investments  \
# 0                       375.0                             15.0
# 1                       286.0                             22.0
# 2                         2.0                              1.0
# 3                         NaN                              NaN
# 4                         6.0                              4.0
#
#    Number of Exits  Number of Lead Investors  Number of Investors  ...  \
# 0            125.0                       1.0                  4.0  ...
# 1            131.0                       NaN                  NaN  ...
# 2              3.0                       9.0                 37.0  ...
# 3              1.0                       1.0                  4.0  ...
# 4              2.0                      11.0                 24.0  ...
#
#   Total Funding Amount Currency Total Funding Amount Currency (in USD)  \
# 0                           USD                           1.257677e+10
# 1                           USD                           3.802820e+07
# 2                           USD                           4.430192e+09
# 3                           USD                           7.706506e+08
# 4                           USD                           2.159578e+10
#
#    Number of Events SEMrush - Monthly Visits  \
# 0              22.0                4,085,844
# 1               NaN                   34.635
# 2              77.0            6,026,399,205
# 3              16.0               32,820,567
# 4             120.0                2,646,155
#
#   SEMrush - Average Visits (6 months)  SEMrush - Visit Duration  \
# 0                           3,553,184                     600.0
# 1                           34,033.67                     392.0
# 2                    3,104,998,131.33                     942.0
# 3                       27,881,933.83                     392.0
# 4                        2,483,475.83                     280.0
#
#   Aberdeen - IT Spend  Aberdeen - IT Spend Currency  \
# 0                 NaN                           NaN
# 1             53801.0                           USD
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4            343977.0                           USD
#
#   Aberdeen - IT Spend Currency (in USD)  \
# 0                                   NaN
# 1                               53801.0
# 2                                   NaN
# 3                                   NaN
# 4                              343977.0
#
#                           Principales inversionistas
# 0   IDG Capital, Prosus & Naspers, Lippo Group, PCCW
# 1                                                NaN
# 2  Andreessen Horowitz, Morgan Stanley, Spark Cap...
# 3  Tencent, JP Morgan Chase, Ontario Teachers' Pe...
# 4  SoftBank, JP Morgan Chase, Goldman Sachs, Insi...
#
# [5 rows x 34 columns]

# %%
import numpy as np
bd_inversionistas = bd_inversionistas[~bd_inversionistas["Principales inversionistas"].isna()]
nodos = bd_inversionistas["Organization Name"][~bd_inversionistas["Principales inversionistas"].isna()].unique()
relaciones = {}
df_inversionistas = {SOURCE: TARGET.split(",") if str(TARGET) != 'nan' else np.nan for SOURCE, TARGET in zip (bd_inversionistas["Organization Name"], bd_inversionistas["Principales inversionistas"]) }
df_inversionistas

lista_tuplas = []
for empresa in df_inversionistas:
    if str(df_inversionistas[empresa]) == 'nan': # relación consigo misma
        None
    else:
        for target in df_inversionistas[empresa]:
            lista_tuplas.append((empresa,target.strip()))

# %%
bd_inversionistas_total = pd.read_excel('Base-inicial.xlsx')
arcos = pd.DataFrame(lista_tuplas, columns=['SOURCE','TARGET'])
total_nodos = set(list(arcos.SOURCE.unique())+list(arcos.TARGET.unique()))
nodos_final = pd.DataFrame(total_nodos).rename(columns={0:"Organization Name"}).merge(bd_inversionistas_total, how="left", on="Organization Name").reset_index().rename(columns={'index':"Id","Organization Name":"Label"})
nodos_final
# Out:
#         Id                          Label  \
# 0        0                       Livspace
# 1        1                         Practo
# 2        2  Court Square Capital Partners
# 3        3                      EnrichHER
# 4        4                    Tony Fadell
# ...    ...                            ...
# 2714  2714         Crescent Cove Advisors
# 2715  2715                           IKEA
# 2716  2716                       SV Angel
# 2717  2717         Crane Venture Partners
# 2718  2718                      SBI Group
#
#                          Headquarters Location Operating Status Company Type  \
# 0                  Bengaluru, Karnataka, India           Active   For Profit
# 1                  Bangalore, Karnataka, India           Active   For Profit
# 2            New York, New York, United States           Active   For Profit
# 3              Atlanta, Georgia, United States           Active   For Profit
# 4                                          NaN              NaN          NaN
# ...                                        ...              ...          ...
# 2714  San Francisco, California, United States           Active   For Profit
# 2715      Delft, Zuid-Holland, The Netherlands           Active   For Profit
# 2716  San Francisco, California, United States           Active          NaN
# 2717           London, England, United Kingdom           Active          NaN
# 2718                       Tokyo, Tokyo, Japan           Active   For Profit
#
#       Number of Investments  Number of Lead Investments  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                    10.000                         4.0
# 3                     8.000                         8.0
# 4                       NaN                         NaN
# ...                     ...                         ...
# 2714                 11.000                         9.0
# 2715                  6.000                         5.0
# 2716                  1.336                        30.0
# 2717                 70.000                        31.0
# 2718                 90.000                        43.0
#
#       Number of Diversity Investments  Number of Exits  \
# 0                                 NaN              NaN
# 1                                 NaN              NaN
# 2                                 2.0              5.0
# 3                                 1.0              NaN
# 4                                 NaN              NaN
# ...                               ...              ...
# 2714                              1.0              1.0
# 2715                              NaN              1.0
# 2716                            235.0            405.0
# 2717                              2.0              NaN
# 2718                              NaN             15.0
#
#       Number of Lead Investors  ...  Total Funding Amount Currency  \
# 0                         11.0  ...                            USD
# 1                          5.0  ...                            USD
# 2                          NaN  ...                            NaN
# 3                          3.0  ...                            USD
# 4                          NaN  ...                            NaN
# ...                        ...  ...                            ...
# 2714                       NaN  ...                            NaN
# 2715                       NaN  ...                            NaN
# 2716                       NaN  ...                            NaN
# 2717                       NaN  ...                            NaN
# 2718                       NaN  ...                            NaN
#
#      Total Funding Amount Currency (in USD) Number of Events  \
# 0                               431577146.0              1.0
# 1                               228246376.0              NaN
# 2                                       NaN              NaN
# 3                                 1550000.0              1.0
# 4                                       NaN              NaN
# ...                                     ...              ...
# 2714                                    NaN              NaN
# 2715                                    NaN              NaN
# 2716                                    NaN              1.0
# 2717                                    NaN              NaN
# 2718                                    NaN              NaN
#
#       SEMrush - Monthly Visits SEMrush - Average Visits (6 months)  \
# 0                      976.201                        2,050,273.67
# 1                   10,946,568                       12,816,835.17
# 2                        6.575                                 NaN
# 3                       15.572                               8.441
# 4                          NaN                                 NaN
# ...                        ...                                 ...
# 2714                       677                               8.321
# 2715               216,519,435                      231,044,819.33
# 2716                    12.985                             5,818.5
# 2717                     1.131                            1,772.33
# 2718                   108.558                           90,793.83
#
#      SEMrush - Visit Duration  Aberdeen - IT Spend  \
# 0                       144.0                  NaN
# 1                       359.0                  NaN
# 2                       941.0           69144131.0
# 3                       238.0                  NaN
# 4                         NaN                  NaN
# ...                       ...                  ...
# 2714                     33.0                  NaN
# 2715                    618.0                  NaN
# 2716                     90.0                  NaN
# 2717                      0.0                  NaN
# 2718                    337.0                  NaN
#
#      Aberdeen - IT Spend Currency  Aberdeen - IT Spend Currency (in USD)  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             USD                             69144131.0
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
# ...                           ...                                    ...
# 2714                          NaN                                    NaN
# 2715                          NaN                                    NaN
# 2716                          NaN                                    NaN
# 2717                          NaN                                    NaN
# 2718                          NaN                                    NaN
#
#                              Principales inversionistas
# 0     Square, Goldman Sachs, Jungle Ventures, Bessem...
# 1     Tencent, Sequoia Capital, Matrix Partners, Seq...
# 2                                                   NaN
# 3     Techstars, Lighthouse Labs RVA, Pipeline Angel...
# 4                                                   NaN
# ...                                                 ...
# 2714                                                NaN
# 2715                                                NaN
# 2716                                                NaN
# 2717                                                NaN
# 2718                                                NaN
#
# [2719 rows x 35 columns]

# %%
arcos_final = arcos.rename(columns={"SOURCE":"LabelSource","TARGET":"LabelTarget"}).merge(
                nodos_final[["Id","Label"]].rename(columns={"Id":"SOURCE"}), left_on="LabelSource",right_on="Label").merge(
                    nodos_final[["Id","Label"]].rename(columns={"Id":"TARGET"}), left_on="LabelTarget",right_on="Label").reset_index()

arcos_final = arcos_final.rename(columns={"index":"Id"})[["Id","SOURCE","TARGET","LabelSource","LabelTarget"]]
arcos_final
# Out:
#         Id  SOURCE  TARGET        LabelSource                  LabelTarget
# 0        0    2682    1651            Tencent                  IDG Capital
# 1        1     304    1651          SenseTime                  IDG Capital
# 2        2    1422    1651             WeRide                  IDG Capital
# 3        3    2238    1651              Shein                  IDG Capital
# 4        4    1516    1651                NIO                  IDG Capital
# ...    ...     ...     ...                ...                          ...
# 5071  5071     990    1129  Backstage Capital             Josef Scarantino
# 5072  5072     375    1315         ESL Gaming                Omnes Capital
# 5073  5073    2422    2407           Bigpoint                  GMT Capital
# 5074  5074    2422    2690           Bigpoint               Peacock Equity
# 5075  5075    2422    2175           Bigpoint  GMT Communications Partners
#
# [5076 rows x 5 columns]

# %%
# Exportar la información de arcos y nodos
nodos_final.to_csv("nodos.csv", index=False)
arcos_final.to_csv("arcos.csv", index=False)
