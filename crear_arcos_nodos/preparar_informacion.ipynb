# %%
import pandas as pd

# %%
bd_inversionistas = pd.read_excel('Base-inicial.xlsx')
bd_inversionistas.head(5)
# Out:
#   Organization Name                       Headquarters Location  \
# 0           Tencent                  Shenzhen, Guangdong, China
# 1    Warburg Pincus           New York, New York, United States
# 2           Twitter    San Francisco, California, United States
# 3           Ubisoft  Montreuil-sous-bois, Ile-de-France, France
# 4            WeWork           New York, New York, United States
#
#   Operating Status Company Type  Number of Investments  \
# 0           Active   For Profit                  693.0
# 1           Active          NaN                  433.0
# 2           Active   For Profit                   10.0
# 3           Active   For Profit                    9.0
# 4           Active   For Profit                    9.0
#
#    Number of Lead Investments  Number of Diversity Investments  \
# 0                       375.0                             15.0
# 1                       286.0                             22.0
# 2                         2.0                              1.0
# 3                         NaN                              NaN
# 4                         6.0                              4.0
#
#    Number of Exits  Number of Lead Investors  Number of Investors  ...  \
# 0            125.0                       1.0                  4.0  ...
# 1            131.0                       NaN                  NaN  ...
# 2              3.0                       9.0                 37.0  ...
# 3              1.0                       1.0                  4.0  ...
# 4              2.0                      11.0                 24.0  ...
#
#   Total Funding Amount Currency Total Funding Amount Currency (in USD)  \
# 0                           USD                           1.257677e+10
# 1                           USD                           3.802820e+07
# 2                           USD                           4.430192e+09
# 3                           USD                           7.706506e+08
# 4                           USD                           2.159578e+10
#
#    Number of Events SEMrush - Monthly Visits  \
# 0              22.0                4,085,844
# 1               NaN                   34.635
# 2              77.0            6,026,399,205
# 3              16.0               32,820,567
# 4             120.0                2,646,155
#
#   SEMrush - Average Visits (6 months)  SEMrush - Visit Duration  \
# 0                           3,553,184                     600.0
# 1                           34,033.67                     392.0
# 2                    3,104,998,131.33                     942.0
# 3                       27,881,933.83                     392.0
# 4                        2,483,475.83                     280.0
#
#   Aberdeen - IT Spend  Aberdeen - IT Spend Currency  \
# 0                 NaN                           NaN
# 1             53801.0                           USD
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4            343977.0                           USD
#
#   Aberdeen - IT Spend Currency (in USD)  \
# 0                                   NaN
# 1                               53801.0
# 2                                   NaN
# 3                                   NaN
# 4                              343977.0
#
#                           Principales inversionistas
# 0   IDG Capital, Prosus & Naspers, Lippo Group, PCCW
# 1                                                NaN
# 2  Andreessen Horowitz, Morgan Stanley, Spark Cap...
# 3  Tencent, JP Morgan Chase, Ontario Teachers' Pe...
# 4  SoftBank, JP Morgan Chase, Goldman Sachs, Insi...
#
# [5 rows x 34 columns]

# %%
import numpy as np
bd_inversionistas = bd_inversionistas[~bd_inversionistas["Principales inversionistas"].isna()]
nodos = bd_inversionistas["Organization Name"][~bd_inversionistas["Principales inversionistas"].isna()].unique()
relaciones = {}
df_inversionistas = {TARGET: SOURCE.split(",") if str(TARGET) != 'nan' else np.nan for TARGET, SOURCE in zip (
                    bd_inversionistas["Organization Name"], bd_inversionistas["Principales inversionistas"]) }
df_inversionistas

lista_tuplas = []
for empresa in df_inversionistas:
    if str(df_inversionistas[empresa]) == 'nan': # relación consigo misma
        None
    else:
        for target in df_inversionistas[empresa]:
            lista_tuplas.append((empresa,target.strip()))

# %%
bd_inversionistas_total = pd.read_excel('Base-inicial.xlsx')
arcos = pd.DataFrame(lista_tuplas, columns=['TARGET','SOURCE'])
total_nodos = set(list(arcos.SOURCE.unique())+list(arcos.TARGET.unique()))
nodos_final = pd.DataFrame(total_nodos).rename(
                columns={0:"Organization Name"}).merge(
                    bd_inversionistas_total, how="inner",
                    on="Organization Name").reset_index().rename(columns={'index':"Id","Organization Name":"Label"})
nodos_final
# Out:
#         Id                Label                     Headquarters Location  \
# 0        0          Mayo Clinic       Rochester, Minnesota, United States
# 1        1     AirTree Ventures  Paddington, Western Australia, Australia
# 2        2            DataRails                Tel Aviv, Tel Aviv, Israel
# 3        3     Felicis Ventures     Menlo Park, California, United States
# 4        4              Netflix      Los Gatos, California, United States
# ...    ...                  ...                                       ...
# 2114  2114  Unstoppable Domains  San Francisco, California, United States
# 2115  2115    Greyhound Capital           London, England, United Kingdom
# 2116  2116       BMW i Ventures  Mountain View, California, United States
# 2117  2117   TenEleven Ventures     Burlingame, California, United States
# 2118  2118   South Park Commons  San Francisco, California, United States
#
#      Operating Status Company Type  Number of Investments  \
# 0              Active   For Profit                   54.0
# 1              Active          NaN                  108.0
# 2              Active   For Profit                    NaN
# 3              Active          NaN                  547.0
# 4              Active   For Profit                    3.0
# ...               ...          ...                    ...
# 2114           Active   For Profit                    NaN
# 2115           Active          NaN                   57.0
# 2116           Active          NaN                  101.0
# 2117           Active          NaN                   55.0
# 2118           Active          NaN                   61.0
#
#       Number of Lead Investments  Number of Diversity Investments  \
# 0                            8.0                             11.0
# 1                           43.0                              5.0
# 2                            NaN                              NaN
# 3                           86.0                            115.0
# 4                            NaN                              NaN
# ...                          ...                              ...
# 2114                         NaN                              NaN
# 2115                         3.0                              2.0
# 2116                        36.0                             21.0
# 2117                        19.0                              2.0
# 2118                         6.0                             19.0
#
#       Number of Exits  Number of Lead Investors  ...  \
# 0                 7.0                       3.0  ...
# 1                 9.0                       NaN  ...
# 2                 NaN                       5.0  ...
# 3               148.0                       NaN  ...
# 4                 1.0                       4.0  ...
# ...               ...                       ...  ...
# 2114              NaN                       5.0  ...
# 2115              5.0                       NaN  ...
# 2116             18.0                       NaN  ...
# 2117             11.0                       NaN  ...
# 2118              6.0                       NaN  ...
#
#       Total Funding Amount Currency Total Funding Amount Currency (in USD)  \
# 0                               USD                           3.861000e+08
# 1                               NaN                                    NaN
# 2                               USD                           1.035000e+08
# 3                               NaN                                    NaN
# 4                               USD                           1.219080e+11
# ...                             ...                                    ...
# 2114                            USD                           6.955997e+06
# 2115                            NaN                                    NaN
# 2116                            NaN                                    NaN
# 2117                            NaN                                    NaN
# 2118                            NaN                                    NaN
#
#      Number of Events  SEMrush - Monthly Visits  \
# 0                40.0               208,741,811
# 1                 NaN                    12.142
# 2                 NaN                    28.497
# 3                 NaN                    10.036
# 4                37.0               872,076,095
# ...               ...                       ...
# 2114              1.0                 1,370,648
# 2115              NaN                       NaN
# 2116              2.0                     2.879
# 2117              1.0                     2.507
# 2118              NaN                    12.953
#
#      SEMrush - Average Visits (6 months) SEMrush - Visit Duration  \
# 0                          194,102,517.5                  513.000
# 1                               7,448.83                  119.000
# 2                              21,384.67                   42.000
# 3                               5,379.17                  127.000
# 4                       1,026,494,647.83                  560.000
# ...                                  ...                      ...
# 2114                           1,643,094                    1.252
# 2115                                 NaN                      NaN
# 2116                            2,646.17                   10.000
# 2117                                 NaN                    8.000
# 2118                            5,194.83                    1.224
#
#       Aberdeen - IT Spend Aberdeen - IT Spend Currency  \
# 0            1.436910e+05                          USD
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4            1.002235e+09                          USD
# ...                   ...                          ...
# 2114                  NaN                          NaN
# 2115                  NaN                          NaN
# 2116                  NaN                          NaN
# 2117                  NaN                          NaN
# 2118                  NaN                          NaN
#
#       Aberdeen - IT Spend Currency (in USD)  \
# 0                              1.436910e+05
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                              1.002235e+09
# ...                                     ...
# 2114                                    NaN
# 2115                                    NaN
# 2116                                    NaN
# 2117                                    NaN
# 2118                                    NaN
#
#                              Principales inversionistas
# 0     National Institutes of Health, U.S. Department...
# 1                                                   NaN
# 2     Vertex Ventures, Innovation Endeavors, Zeev Ve...
# 3                                                   NaN
# 4     Institutional Venture Partners, TCV, Foundatio...
# ...                                                 ...
# 2114  Gaingels, Draper Associates, Protocol Labs, Co...
# 2115                                                NaN
# 2116                                                NaN
# 2117                                                NaN
# 2118                                                NaN
#
# [2119 rows x 35 columns]

# %%
# mediante merge se asegura que estamos fusionando solamente los nodos que tienen información, dado que el método es inner
arcos_final = arcos.rename(columns={"SOURCE":"LabelSource","TARGET":"LabelTarget"}).merge(
                nodos_final[["Id","Label"]].rename(columns={"Id":"SOURCE"}), 
                left_on="LabelSource",right_on="Label").merge(
                    nodos_final[["Id","Label"]].rename(columns={"Id":"TARGET"}), 
                    left_on="LabelTarget",right_on="Label").reset_index()

arcos_final = arcos_final.rename(columns={"index":"Id"})[["Id","SOURCE","TARGET","LabelSource","LabelTarget"]]
arcos_final
# Out:
#         Id  SOURCE  TARGET            LabelSource                LabelTarget
# 0        0    1433     946            IDG Capital                    Tencent
# 1        1     861     946       Prosus & Naspers                    Tencent
# 2        2     636     946            Lippo Group                    Tencent
# 3        3    2058     946                   PCCW                    Tencent
# 4        4    1433     940            IDG Capital                  SenseTime
# ...    ...     ...     ...                    ...                        ...
# 4176  4176     583     643                Bitmain                  DoraHacks
# 4177  4177    1851     643      ArkStream Capital                  DoraHacks
# 4178  4178     263     643      8 Decimal Capital                  DoraHacks
# 4179  4179    1815    1206  Nikko AssetManagement  ARK Investment Management
# 4180  4180    1429    2044          Omnes Capital                 ESL Gaming
#
# [4181 rows x 5 columns]

# %%
# Exportar la información de arcos y nodos
nodos_final.to_csv("nodos.csv", index=False)
arcos_final.to_csv("arcos.csv", index=False)
